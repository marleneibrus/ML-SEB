# %% [markdown]
# # Data understanding

# %% [markdown]
# ### Import packages and dataset

# %%
import pandas as pd
from plotnine import ggplot, aes, geom_bar, geom_line

# %%
customers = pd.read_csv('../Data/synthetic_sme_customers_processed.csv')
transactions = pd.read_csv('../Data/synthetic_sme_transactions_processed.csv')
# Out:
# /tmp/ipykernel_1553322/3594939439.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# ### Overview of data

# %% [markdown]
# #### Example data

# %%
customers.head()
# Out:
#                                              cust_id customer_type  \
# 0  3caf82febb1d4e64b140893d9e89d748115ec5b70455e1...           SME
# 1  fd0d32ecf697980ff5b750d18fe6f8e9f96f2e31fba130...           SME
# 2  320b10457c9c109c2b4f00b0fecac1cc8cb7c2da8ad936...           SME
# 3  d4d7e033ed758bb075ad96435d4afb505b7a4059aa3f37...           SME
# 4  e9b8374b1f3ae04cc65672bc5907726d962edb35e05736...           SME
#
#    parent_company_flag                                        CUST_GRP_ID  \
# 0                    0  eefcfda39744d0f4c7d1f1f6f13a53dbf49f7281de5de0...
# 1                    1                                                NaN
# 2                    1                                                NaN
# 3                    1                                                NaN
# 4                    1                                                NaN
#
#      BRTH_DT language
# 0  2005-2009      ENG
# 1  2015-2019      EST
# 2  2020-2024      EST
# 3  2020-2024      EST
# ...

# %%
transactions.head()
# Out:
#    WeekDay        Channel                                            cust_id  \
# 0        5            POS  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 1        2  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 2        3  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 3        7  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 4        3  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
#
#   D_C Currency_trx  Amount_EUR  \
# 0   D          EUR    7.518036
# 1   D          EUR    0.200481
# 2   D          EUR    1.002405
# 3   C          EUR    0.010024
# 4   D          EUR    1.002405
#
#                                        Customer_IBAN  \
# 0  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# 1  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# 2  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# 3  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# ...

# %% [markdown]
# #### Data description

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cust_id              1000 non-null   object
#  1   customer_type        1000 non-null   object
#  2   parent_company_flag  1000 non-null   int64
#  3   CUST_GRP_ID          348 non-null    object
#  4   BRTH_DT              1000 non-null   object
#  5   language             1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542016 entries, 0 to 2542015
# Data columns (total 13 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   WeekDay              int64
#  1   Channel              object
#  2   cust_id              object
#  3   D_C                  object
#  4   Currency_trx         object
#  5   Amount_EUR           float64
#  6   Customer_IBAN        object
#  7   Counterparty_IBAN    object
#  8   Amount_Orig          float64
#  9   currency             object
#  10  MCC                  float64
#  11  country_of_merchant  object
#  12  BookingDatetime      object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 252.1+ MB

# %% [markdown]
# #### Value counts of categoricals with with more than 2 values

# %%
customers.BRTH_DT.value_counts()
# Out:
# BRTH_DT
# 2015-2019    249
# 2010-2014    198
# 2005-2009    164
# 1995-1999    163
# 2000-2004    113
# 2020-2024     87
# 1990-1994     17
# 1900-1904      5
# 1970-1974      2
# 1915-1919      1
# 1965-1969      1
# Name: count, dtype: int64

# %%
transactions.Channel.value_counts()
# Out:
# Channel
# Internet Bank             2157606
# POS                        180480
# Mobile Bank                123912
# E-Invoice                   38834
# ATM                         30742
# Standing Payment Order       6424
# Branch                       4006
# Paperless service              12
# Name: count, dtype: int64

# %%
transactions.Currency_trx.value_counts()
# Out:
# Currency_trx
# EUR    2537364
# USD       3466
# SEK        932
# GBP        124
# DKK         86
# CAD         30
# NOK         14
# Name: count, dtype: int64

# %%
transactions.MCC.value_counts()
# Out:
# MCC
# 5211.0    20258
# 5411.0    13952
# 5541.0    12302
# 5542.0    11018
# 5251.0     9192
#           ...
# 3665.0        2
# 3509.0        2
# 8641.0        2
# 3387.0        2
# 5975.0        2
# Name: count, Length: 298, dtype: int64

# %%
transactions.country_of_merchant.value_counts()
# Out:
# country_of_merchant
# EE     134810
# IE       9518
# LV       5336
# FI       5208
# NL       3460
#         ...
# MV          2
# MU          2
# MK          2
# GI          2
# MC          2
# Name: count, Length: 78, dtype: int64

# %% [markdown]
# ### NaN-values, duplicates and outliers

# %% [markdown]
# #### NaN values per column

# %%
customers.isna().sum(axis=0)
# Out:
# cust_id                  0
# customer_type            0
# parent_company_flag      0
# CUST_GRP_ID            652
# BRTH_DT                  0
# language                 0
# dtype: int64

# %%
transactions.isna().sum(axis=0)
# Out:
# WeekDay                      0
# Channel                      0
# cust_id                      0
# D_C                          0
# Currency_trx                 0
# Amount_EUR                   0
# Customer_IBAN               32
# Counterparty_IBAN       121318
# Amount_Orig                  0
# currency                     0
# MCC                    2359926
# country_of_merchant    2359926
# BookingDatetime              0
# dtype: int64

# %% [markdown]
# #### Number of duplicates

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
transactions.duplicated().sum()
# Out:
# np.int64(1271449)

# %% [markdown]
# #### Visual value distributions

# %%
(
    ggplot(data=transactions)
    + geom_bar(aes(x='Amount_EUR', color='WeekDay'))
)
