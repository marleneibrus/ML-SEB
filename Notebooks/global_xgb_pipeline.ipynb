# %% [markdown]
# # Preparing cashflow features for an training a global XGBoost model

# %% [markdown]
# ### Project members:
# - Marlene Ibrus
# - Maare Karmen Oras
# - Aleksandr Volžinski

# %% [markdown]
# In this file, we will create necessary agregate features for cashflow and creating the train-validation-test split. ...

# %% [markdown]
# ## I. Imports

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import xgboost as xgb
from xgboost import XGBRegressor
from xgboost.callback import EarlyStopping
import joblib
import optuna
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## II. Load customer and transaction data

# %%
df_customer = pd.read_csv('../Data/synthetic_sme_customers_processed.csv')
df_customer.head()
# Out:
#                                              cust_id customer_type  \
# 0  3caf82febb1d4e64b140893d9e89d748115ec5b70455e1...           SME
# 1  fd0d32ecf697980ff5b750d18fe6f8e9f96f2e31fba130...           SME
# 2  320b10457c9c109c2b4f00b0fecac1cc8cb7c2da8ad936...           SME
# 3  d4d7e033ed758bb075ad96435d4afb505b7a4059aa3f37...           SME
# 4  e9b8374b1f3ae04cc65672bc5907726d962edb35e05736...           SME
#
#    parent_company_flag                                        CUST_GRP_ID  \
# 0                    0  eefcfda39744d0f4c7d1f1f6f13a53dbf49f7281de5de0...
# 1                    1                                                NaN
# 2                    1                                                NaN
# 3                    1                                                NaN
# 4                    1                                                NaN
#
#      BRTH_DT language
# 0  2005-2009      ENG
# 1  2015-2019      EST
# 2  2020-2024      EST
# 3  2020-2024      EST
# 4  2020-2024      EST

# %%
df_transaction = pd.read_csv('../Data/synthetic_sme_transactions_processed.csv')
df_transaction.head()
# Out:
#    WeekDay        Channel                                            cust_id  \
# 0        5            POS  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 1        2  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 2        3  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 3        7  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 4        3  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
#
#   D_C Currency_trx  Amount_EUR  \
# 0   D          EUR    7.518036
# 1   D          EUR    0.200481
# 2   D          EUR    1.002405
# 3   C          EUR    0.010024
# 4   D          EUR    1.002405
#
#                                        Customer_IBAN  \
# 0  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# 1  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# 2  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# 3  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# 4  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
#
#                                    Counterparty_IBAN  Amount_Orig currency  \
# 0  7ecc6d620a9ea4170231178c236206770eb7a4785d2a6c...     7.518036      EUR
# 1  7ecc6d620a9ea4170231178c236206770eb7a4785d2a6c...     0.200481      EUR
# 2  7ecc6d620a9ea4170231178c236206770eb7a4785d2a6c...     1.002405      EUR
# 3  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...     0.010024      EUR
# 4  7ecc6d620a9ea4170231178c236206770eb7a4785d2a6c...     1.002405      EUR
#
#       MCC country_of_merchant      BookingDatetime
# 0  5271.0                 EE   2023-01-27 10:00:28
# 1     NaN                 NaN  2023-01-17 02:14:14
# 2     NaN                 NaN  2023-02-08 02:00:18
# 3     NaN                 NaN  2023-01-01 03:56:39
# 4     NaN                 NaN  2023-03-08 02:06:48

# %% [markdown]
# ## III. Merge datasets and clean datetime

# %%
df_total = pd.merge(df_transaction, df_customer, on='cust_id', how='left')
df_total = df_total[np.abs(df_total['Amount_EUR']) >= 0.01]
df_total['BookingDatetime'] = pd.to_datetime(df_total['BookingDatetime'])
df_total['Amount_EUR'] = df_total['Amount_EUR'].round(2)
df_total['Week'] = df_total['BookingDatetime'].dt.isocalendar().week
df_total['Month'] = df_total['BookingDatetime'].dt.month

# %%
df_total.head()
# Out:
#    WeekDay        Channel                                            cust_id  \
# 0        5            POS  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 1        2  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 2        3  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 3        7  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
# 4        3  Internet Bank  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...
#
#   D_C Currency_trx  Amount_EUR  \
# 0   D          EUR        7.52
# 1   D          EUR        0.20
# 2   D          EUR        1.00
# 3   C          EUR        0.01
# 4   D          EUR        1.00
#
#                                        Customer_IBAN  \
# 0  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# 1  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# 2  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# 3  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
# 4  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...
#
#                                    Counterparty_IBAN  Amount_Orig currency  \
# 0  7ecc6d620a9ea4170231178c236206770eb7a4785d2a6c...     7.518036      EUR
# 1  7ecc6d620a9ea4170231178c236206770eb7a4785d2a6c...     0.200481      EUR
# 2  7ecc6d620a9ea4170231178c236206770eb7a4785d2a6c...     1.002405      EUR
# 3  3a8c99d1e8caf60ddbc4b9865b0947f981c90980f3fab2...     0.010024      EUR
# 4  7ecc6d620a9ea4170231178c236206770eb7a4785d2a6c...     1.002405      EUR
#
#       MCC country_of_merchant     BookingDatetime customer_type  \
# 0  5271.0                 EE  2023-01-27 10:00:28           SME
# 1     NaN                 NaN 2023-01-17 02:14:14           SME
# 2     NaN                 NaN 2023-02-08 02:00:18           SME
# 3     NaN                 NaN 2023-01-01 03:56:39           SME
# 4     NaN                 NaN 2023-03-08 02:06:48           SME
#
#    parent_company_flag CUST_GRP_ID    BRTH_DT language  Week  Month
# 0                    1         NaN  1995-1999      RUS     4      1
# 1                    1         NaN  1995-1999      RUS     3      1
# 2                    1         NaN  1995-1999      RUS     6      2
# 3                    1         NaN  1995-1999      RUS    52      1
# 4                    1         NaN  1995-1999      RUS    10      3

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2540072 entries, 0 to 2542015
# Data columns (total 20 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   WeekDay              int64
#  1   Channel              object
#  2   cust_id              object
#  3   D_C                  object
#  4   Currency_trx         object
#  5   Amount_EUR           float64
#  6   Customer_IBAN        object
#  7   Counterparty_IBAN    object
#  8   Amount_Orig          float64
#  9   currency             object
#  10  MCC                  float64
#  11  country_of_merchant  object
#  12  BookingDatetime      datetime64[ns]
#  13  customer_type        object
#  14  parent_company_flag  int64
#  15  CUST_GRP_ID          object
#  16  BRTH_DT              object
#  17  language             object
#  18  Week                 UInt32
#  19  Month                int32
# dtypes: UInt32(1), datetime64[ns](1), float64(3), int32(1), int64(2), object(12)
# memory usage: 390.0+ MB

# %%
df_total.shape
# Out:
# (2540072, 20)

# %%
print(f"Unique customers: {df_total['cust_id'].nunique()}")
# Out:
# Unique customers: 958

# %% [markdown]
# ## IV. Compute daily net cash flow per customer

# %%
df_total['flow'] = df_total.apply(lambda x: x['Amount_EUR'] if x['D_C'] == 'D' else -x['Amount_EUR'], axis=1)

daily_cashflow = (
    df_total.groupby(['cust_id', pd.Grouper(key='BookingDatetime', freq='D')])['flow']
      .sum()
      .reset_index()
      .rename(columns={'flow': 'net_flow'})
)

print(f"Daily cashflow shape: {daily_cashflow.shape}")
print(daily_cashflow.head())
# Out:
# Daily cashflow shape: (270433, 3)
#                                              cust_id BookingDatetime  net_flow
# 0  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      2023-01-01     -0.02
# 1  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      2023-01-08      2.00
# 2  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      2023-01-16    280.68
# 3  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      2023-01-17      0.40
# 4  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      2023-01-27     15.04

# %%
#  Rename 'BookingDatetime' to 'date' and normalize
daily = daily_cashflow.copy()
daily = daily.rename(columns={'BookingDatetime': 'date'})
daily['date'] = pd.to_datetime(daily['date']).dt.normalize()

# %% [markdown]
# ## V. Reindex per customer to fill missing dates

# %%
def reindex_customer(group):
    idx = pd.date_range(group['date'].min(), group['date'].max(), freq='D')
    g = group.set_index('date').reindex(idx).rename_axis('date').reset_index()
    g['cust_id'] = group['cust_id'].iloc[0]
    g['net_flow'] = g['net_flow'].fillna(0.0)
    return g

# %%
daily_full = daily.groupby('cust_id', as_index=False, group_keys=False).apply(reindex_customer).reset_index(drop=True)

# %%
daily_full.describe(include='all')
# Out:
#                                  date  \
# count                          682527
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-12-26 14:41:11.163779072
# min               2023-01-01 00:00:00
# 25%               2023-06-29 00:00:00
# 50%               2023-12-25 00:00:00
# 75%               2024-06-23 00:00:00
# max               2024-12-31 00:00:00
# std                               NaN
#
#                                                   cust_id      net_flow
# count                                              682527  6.825270e+05
# unique                                                958           NaN
# top     7e3a7fac7a24ad6e091f0fe698a30c42a043b1953b9243...           NaN
# freq                                                  731           NaN
# mean                                                  NaN  4.660542e+00
# min                                                   NaN -7.808635e+06
# 25%                                                   NaN  0.000000e+00
# 50%                                                   NaN  0.000000e+00
# 75%                                                   NaN  0.000000e+00
# max                                                   NaN  7.803744e+06
# std                                                   NaN  3.028270e+04

# %% [markdown]
# ## Create a 7-day future target
#
# Since we aim to predict for a 7-day window, the we use the last 7 days to create that prediction. We use a rolling sum shifted by -7 to avoid leakage. Once `target_7d` is created, drop rows where `target_7d` is `NaN`.

# %%
daily_full = daily_full.sort_values(['cust_id', 'date']).reset_index(drop=True)
daily_full['target_7d'] = (
    daily_full
    .groupby('cust_id')['net_flow']
    .transform(lambda x: x.rolling(window=7, min_periods=7).sum().shift(-7))
)

# %%
daily_full = daily_full[~daily_full['target_7d'].isna()].reset_index(drop=True)

# %% [markdown]
# ## Create lag features using past data only

# %%
windows = [7, 14, 30]
for w in windows:
    daily_full[f'roll_sum_{w}'] = daily_full.groupby('cust_id')['net_flow'].transform(lambda x: x.rolling(window=w, min_periods=1).sum())
    daily_full[f'roll_mean_{w}'] = daily_full.groupby('cust_id')['net_flow'].transform(lambda x: x.rolling(window=w, min_periods=1).mean())
    daily_full[f'roll_std_{w}'] = daily_full.groupby('cust_id')['net_flow'].transform(lambda x: x.rolling(window=w, min_periods=1).std().fillna(0))

# %%
daily_full['lag_1'] = daily_full.groupby('cust_id')['net_flow'].shift(1).fillna(0)
daily_full['lag_7_sum'] = daily_full.groupby('cust_id')['net_flow'].transform(lambda x: x.shift(1).rolling(7, min_periods=1).sum()).fillna(0)

# %%
daily_full['dayofweek'] = daily_full['date'].dt.dayofweek
daily_full['is_weekend'] = daily_full['dayofweek'].isin([5,6]).astype(int)
daily_full['day'] = daily_full['date'].dt.day
daily_full['month'] = daily_full['date'].dt.month
daily_full['year'] = daily_full['date'].dt.year

# %%
daily_full.head()
# Out:
#         date                                            cust_id  net_flow  \
# 0 2023-01-01  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...     -0.02
# 1 2023-01-02  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      0.00
# 2 2023-01-03  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      0.00
# 3 2023-01-04  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      0.00
# 4 2023-01-05  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      0.00
#
#    target_7d  roll_sum_7  roll_mean_7  roll_std_7  roll_sum_14  roll_mean_14  \
# 0        2.0       -0.02    -0.020000    0.000000        -0.02     -0.020000
# 1        2.0       -0.02    -0.010000    0.014142        -0.02     -0.010000
# 2        2.0       -0.02    -0.006667    0.011547        -0.02     -0.006667
# 3        2.0       -0.02    -0.005000    0.010000        -0.02     -0.005000
# 4        2.0       -0.02    -0.004000    0.008944        -0.02     -0.004000
#
#    roll_std_14  roll_sum_30  roll_mean_30  roll_std_30  lag_1  lag_7_sum  \
# 0     0.000000        -0.02     -0.020000     0.000000   0.00       0.00
# 1     0.014142        -0.02     -0.010000     0.014142  -0.02      -0.02
# 2     0.011547        -0.02     -0.006667     0.011547   0.00      -0.02
# 3     0.010000        -0.02     -0.005000     0.010000   0.00      -0.02
# 4     0.008944        -0.02     -0.004000     0.008944   0.00      -0.02
#
#    dayofweek  is_weekend  day  month  year
# 0          6           1    1      1  2023
# 1          0           0    2      1  2023
# 2          1           0    3      1  2023
# 3          2           0    4      1  2023
# 4          3           0    5      1  2023

# %%
daily_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675821 entries, 0 to 675820
# Data columns (total 20 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   date          675821 non-null  datetime64[ns]
#  1   cust_id       675821 non-null  object
#  2   net_flow      675821 non-null  float64
#  3   target_7d     675821 non-null  float64
#  4   roll_sum_7    675821 non-null  float64
#  5   roll_mean_7   675821 non-null  float64
#  6   roll_std_7    675821 non-null  float64
#  7   roll_sum_14   675821 non-null  float64
#  8   roll_mean_14  675821 non-null  float64
#  9   roll_std_14   675821 non-null  float64
#  10  roll_sum_30   675821 non-null  float64
#  11  roll_mean_30  675821 non-null  float64
#  12  roll_std_30   675821 non-null  float64
#  13  lag_1         675821 non-null  float64
#  14  lag_7_sum     675821 non-null  float64
#  15  dayofweek     675821 non-null  int32
#  16  is_weekend    675821 non-null  int32
#  17  day           675821 non-null  int32
#  18  month         675821 non-null  int32
#  19  year          675821 non-null  int32
# dtypes: datetime64[ns](1), float64(13), int32(5), object(1)
# memory usage: 90.2+ MB

# %%
daily_full.describe(include='all')
# Out:
#                                  date  \
# count                          675821
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-12-23 03:09:33.047004928
# min               2023-01-01 00:00:00
# 25%               2023-06-27 00:00:00
# 50%               2023-12-21 00:00:00
# 75%               2024-06-18 00:00:00
# max               2024-12-24 00:00:00
# std                               NaN
#
#                                                   cust_id      net_flow  \
# count                                              675821  6.758210e+05
# unique                                                958           NaN
# top     7e3a7fac7a24ad6e091f0fe698a30c42a043b1953b9243...           NaN
# freq                                                  724           NaN
# mean                                                  NaN  4.881056e+00
# min                                                   NaN -7.808635e+06
# 25%                                                   NaN  0.000000e+00
# 50%                                                   NaN  0.000000e+00
# 75%                                                   NaN  0.000000e+00
# max                                                   NaN  7.803744e+06
# std                                                   NaN  3.029584e+04
#
#            target_7d    roll_sum_7   roll_mean_7    roll_std_7   roll_sum_14  \
# count   6.758210e+05  6.758210e+05  6.758210e+05  6.758210e+05  6.758210e+05
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    6.516134e+01  2.082984e+01 -4.685244e+00  4.844398e+03  4.467088e+01
# min    -7.951560e+06 -7.951560e+06 -3.612219e+06  0.000000e+00 -8.012290e+06
# 25%    -4.933000e+02 -4.870000e+02 -6.978571e+01  1.137673e+01 -1.014040e+03
# 50%     0.000000e+00  0.000000e+00  0.000000e+00  2.734343e+02  0.000000e+00
# 75%     6.580400e+02  6.556400e+02  9.406286e+01  1.604625e+03  1.144640e+03
# max     8.022838e+06  8.022838e+06  1.146120e+06  4.508648e+06  5.630463e+06
# std     5.680235e+04  5.786139e+04  9.772262e+03  3.128271e+04  7.463493e+04
#
#         roll_mean_14   roll_std_14   roll_sum_30  roll_mean_30   roll_std_30  \
# count   6.758210e+05  6.758210e+05  6.758210e+05  6.758210e+05  6.758210e+05
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean   -8.517485e+00  5.485513e+03  6.044327e+01 -1.483346e+01  6.100757e+03
# min    -3.612219e+06  0.000000e+00 -7.954514e+06 -3.612219e+06  0.000000e+00
# 25%    -7.317286e+01  7.605970e+01 -1.539680e+03 -5.265600e+01  1.506903e+02
# 50%     0.000000e+00  4.497368e+02  1.900000e+00  6.333333e-02  6.391042e+02
# 75%     8.258571e+01  2.234617e+03  1.454440e+03  4.985733e+01  2.785145e+03
# max     4.021759e+05  3.064111e+06  8.042096e+06  3.472767e+05  2.554225e+06
# std     7.773696e+03  3.086267e+04  1.023107e+05  6.958585e+03  3.060999e+04
#
#                lag_1     lag_7_sum      dayofweek     is_weekend  \
# count   6.758210e+05  6.758210e+05  675821.000000  675821.000000
# unique           NaN           NaN            NaN            NaN
# top              NaN           NaN            NaN            NaN
# freq             NaN           NaN            NaN            NaN
# mean    3.222172e+00  1.889229e+01       2.998377       0.285835
# min    -7.808635e+06 -7.951560e+06       0.000000       0.000000
# 25%     0.000000e+00 -4.839800e+02       1.000000       0.000000
# 50%     0.000000e+00  0.000000e+00       3.000000       0.000000
# 75%     0.000000e+00  6.529600e+02       5.000000       1.000000
# max     7.803744e+06  8.022838e+06       6.000000       1.000000
# std     3.027316e+04  5.782026e+04       2.002412       0.451811
#
#                   day          month           year
# count   675821.000000  675821.000000  675821.000000
# unique            NaN            NaN            NaN
# top               NaN            NaN            NaN
# freq              NaN            NaN            NaN
# mean        15.617372       6.411582    2023.485799
# min          1.000000       1.000000    2023.000000
# 25%          8.000000       3.000000    2023.000000
# 50%         16.000000       6.000000    2023.000000
# 75%         23.000000       9.000000    2024.000000
# max         31.000000      12.000000    2024.000000
# std          8.775931       3.401053       0.499799

# %% [markdown]
# ## VI. Merge static customer features

# %%
cust_static = df_customer.copy()

# %%
cust_static['BRTH_DT'] = pd.to_datetime(cust_static['BRTH_DT'], errors='coerce')
latest_date = daily_full['date'].max()
cust_static['age'] = ((latest_date - cust_static['BRTH_DT']).dt.days // 365).fillna(-1).astype(int)

# %%
keep_cols = ['cust_id', 'customer_type', 'parent_company_flag', 'CUST_GRP_ID', 'language', 'age']
cust_static = cust_static[[c for c in keep_cols if c in cust_static.columns]]

# %%
df = daily_full.merge(cust_static, on='cust_id', how='left')

# %%
df.head()
# Out:
#         date                                            cust_id  net_flow  \
# 0 2023-01-01  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...     -0.02
# 1 2023-01-02  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      0.00
# 2 2023-01-03  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      0.00
# 3 2023-01-04  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      0.00
# 4 2023-01-05  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...      0.00
#
#    target_7d  roll_sum_7  roll_mean_7  roll_std_7  roll_sum_14  roll_mean_14  \
# 0        2.0       -0.02    -0.020000    0.000000        -0.02     -0.020000
# 1        2.0       -0.02    -0.010000    0.014142        -0.02     -0.010000
# 2        2.0       -0.02    -0.006667    0.011547        -0.02     -0.006667
# 3        2.0       -0.02    -0.005000    0.010000        -0.02     -0.005000
# 4        2.0       -0.02    -0.004000    0.008944        -0.02     -0.004000
#
#    roll_std_14  ...  dayofweek  is_weekend  day  month  year  customer_type  \
# 0     0.000000  ...          6           1    1      1  2023            SME
# 1     0.014142  ...          0           0    2      1  2023            SME
# 2     0.011547  ...          1           0    3      1  2023            SME
# 3     0.010000  ...          2           0    4      1  2023            SME
# 4     0.008944  ...          3           0    5      1  2023            SME
#
#    parent_company_flag  CUST_GRP_ID  language  age
# 0                    1          NaN       RUS   -1
# 1                    1          NaN       RUS   -1
# 2                    1          NaN       RUS   -1
# 3                    1          NaN       RUS   -1
# 4                    1          NaN       RUS   -1
#
# [5 rows x 25 columns]

# %% [markdown]
# ## VII. Encode categorical variables

# %%
cat_cols = [c for c in ['customer_type', 'CUST_GRP_ID', 'language'] if c in df.columns]
for c in cat_cols:
    df[c] = df[c].astype('category').cat.codes.fillna(-1).astype(int)

# %% [markdown]
# ## VIII. Prepare matrix

# %%
label_col = 'target_7d'
ignore_cols = ['cust_id', 'date', label_col]
feature_cols = [c for c in df.columns if c not in ignore_cols]

# %%
X = df[feature_cols]
y = df[label_col].values

# %%
print("Feature columns used:", feature_cols)
print("Total rows:", len(df))
# Out:
# Feature columns used: ['net_flow', 'roll_sum_7', 'roll_mean_7', 'roll_std_7', 'roll_sum_14', 'roll_mean_14', 'roll_std_14', 'roll_sum_30', 'roll_mean_30', 'roll_std_30', 'lag_1', 'lag_7_sum', 'dayofweek', 'is_weekend', 'day', 'month', 'year', 'customer_type', 'parent_company_flag', 'CUST_GRP_ID', 'language', 'age']
# Total rows: 675821

# %% [markdown]
# ## IX. Create a chronological train/valid/test split by date
#
# Split dates by quantiles of the global date (70%, 15%, 15%)

# %%
date_values = df['date']
train_end = date_values.quantile(0.70)
valid_end = date_values.quantile(0.85)

# %%
train_idx = df['date'] <= train_end
valid_idx = (df['date'] > train_end) & (df['date'] <= valid_end)
test_idx = df['date'] > valid_end

# %%
X_train, y_train = X[train_idx], y[train_idx]
X_valid, y_valid = X[valid_idx], y[valid_idx]
X_test,  y_test  = X[test_idx],  y[test_idx]

# %%
print(f"Train rows: {len(X_train)}  Valid rows: {len(X_valid)}  Test rows: {len(X_test)}")
# Out:
# Train rows: 473547  Valid rows: 101290  Test rows: 100984

# %% [markdown]
# ## X. Create XGBoost DMatrix and set parameters
#
# As we are able to use GPU acceleration for XGBoost, we will use the necessary GPU-specific parameters for training.

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dvalid = xgb.DMatrix(X_valid, label=y_valid)
dtest  = xgb.DMatrix(X_test, label=y_test)

# %%
params_gpu = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'tree_method': 'hist',       # Use GPU-accelerated histogram algorithm
    'device': 'gpu',                     # GPU device index (0 = first GPU)
    'predictor': 'gpu_predictor',    # Use GPU for predictions
    'learning_rate': 0.05,
    'max_depth': 6,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'lambda': 1.0,
    'alpha': 0.0,
    'seed': 42,
    'verbosity': 1
}

# %%
evallist = [(dtrain, 'train'), (dvalid, 'valid')]

# %% [markdown]
# ## XI. Train with early stopping

# %%
bst_gpu = xgb.train(
    params_gpu,
    dtrain,
    num_boost_round=2000,
    evals=evallist,
    early_stopping_rounds=50,
    verbose_eval=50
)
# Out:
# [0]	train-rmse:59127.93899	valid-rmse:47739.30823
# [50]	train-rmse:51960.56780	valid-rmse:46338.94651
# [76]	train-rmse:50901.39948	valid-rmse:46382.67422

# %% [markdown]
# ## XII. Evaluate on test set and determine feature importance

# %%
y_pred_test = bst_gpu.predict(dtest, iteration_range=(0, bst_gpu.best_iteration + 1))
rmse = mean_squared_error(y_test, y_pred_test) ** 0.5
mae = mean_absolute_error(y_test, y_pred_test)
mape = np.mean(np.abs((y_test - y_pred_test) / np.where(y_test==0, 1e-6, y_test))) * 100

# %%
print("\nTEST METRICS")
print(f"RMSE: {rmse:.4f}")
print(f"MAE : {mae:.4f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# TEST METRICS
# RMSE: 50364.5492
# MAE : 10019.3850
# MAPE: 2643003586437408.00%

# %%
fi = bst_gpu.get_score(importance_type='gain')
fi_df = pd.DataFrame([
    {'feature': k, 'gain': v} for k, v in fi.items()
]).sort_values('gain', ascending=False)

# %%
print("\nTop features by gain:")
print(fi_df.head(20))
# Out:
# Top features by gain:
#                 feature          gain
# 9           roll_std_30  3.959649e+12
# 15                month  3.851449e+12
# 10                lag_1  3.261741e+12
# 4           roll_sum_14  3.193916e+12
# 5          roll_mean_14  3.030790e+12
# 18          CUST_GRP_ID  2.743424e+12
# 17  parent_company_flag  2.488570e+12
# 0              net_flow  2.394373e+12
# 12            dayofweek  2.219355e+12
# 14                  day  1.871676e+12
# 2           roll_mean_7  1.865525e+12
# 7           roll_sum_30  1.813482e+12
# 1            roll_sum_7  1.794066e+12
# 3            roll_std_7  1.749569e+12
# 19             language  1.692736e+12
# 6           roll_std_14  1.522094e+12
# 8          roll_mean_30  1.359352e+12
# 11            lag_7_sum  1.309898e+12
# 16                 year  9.778478e+11
# 13           is_weekend  1.316644e+11

# %% [markdown]
# ## XIII. Hyperparameter tuning
#
# The previous results were not good (to say the least), so we will use `Optuna` to define the search space for hyperparameters and run a study to fin the best ones.

# %%
def objective(trial):
    params = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'tree_method': 'hist',
        'device': 'cuda',      # <- works for ALL versions
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'lambda': trial.suggest_float('lambda', 0, 10),
        'alpha': trial.suggest_float('alpha', 0, 10),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
    }

    evals = [(dtrain, 'train'), (dvalid, 'valid')]

    model = xgb.train(
        params,
        dtrain,
        num_boost_round=2000,
        evals=evals,
        early_stopping_rounds=100,   # <– works in ALL versions
        verbose_eval=False
    )

    preds = model.predict(dvalid)
    rmse = mean_squared_error(y_valid, preds) ** 0.5
    return rmse

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials
# [I 2025-12-09 21:03:03,954] Trial 21 finished with value: 45064.77285141793 and parameters: {'learning_rate': 0.020526110518480734, 'max_depth': 5, 'subsample': 0.6627110957994533, 'colsample_bytree': 0.7703372948971184, 'lambda': 0.02990031899091733, 'alpha': 0.4130832013878276, 'min_child_weight': 18}. Best is trial 21 with value: 45064.77285141793.
# [I 2025-12-09 21:03:04,918] Trial 22 finished with value: 45122.838710928336 and parameters: {'learning_rate': 0.02145136614931284, 'max_depth': 5, 'subsample': 0.6372913024558333, 'colsample_bytree': 0.7602576019974738, 'lambda': 0.2076424262553738, 'alpha': 0.10433232896521877, 'min_child_weight': 18}. Best is trial 21 with value: 45064.77285141793.
# [I 2025-12-09 21:03:05,986] Trial 23 finished with value: 45257.18802729526 and parameters: {'learning_rate': 0.023627858533575474, 'max_depth': 6, 'subsample': 0.6252838974074238, 'colsample_bytree': 0.7739928263804394, 'lambda': 0.1148167468631594, 'alpha': 0.021147860629865012, 'min_child_weight': 20}. Best is trial 21 with value: 45064.77285141793.
# [I 2025-12-09 21:03:06,887] Trial 24 finished with value: 45507.145822556275 and parameters: {'learning_rate': 0.03417788889803725, 'max_depth': 5, 'subsample': 0.620732467997828, 'colsample_bytree': 0.765573322392295, 'lambda': 0.049139981737192334, 'alpha': 1.7741083036704268, 'min_child_weight': 18}. Best is trial 21 with value: 45064.77285141793.
# [I 2025-12-09 21:03:08,305] Trial 25 finished with value: 44856.602246820126 and parameters: {'learning_rate': 0.02053217788872651, 'max_depth': 8, 'subsample': 0.6759051394348353, 'colsample_bytree': 0.7150327462599864, 'lambda': 0.9281002744634381, 'alpha': 0.009440829249541871, 'min_child_weight': 18}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:09,797] Trial 26 finished with value: 44993.730856398164 and parameters: {'learning_rate': 0.019402685251266313, 'max_depth': 8, 'subsample': 0.672082977215061, 'colsample_bytree': 0.7051479939070334, 'lambda': 0.9807183032937579, 'alpha': 1.4857022210454123, 'min_child_weight': 17}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:11,228] Trial 27 finished with value: 45326.17953668411 and parameters: {'learning_rate': 0.031065705593103746, 'max_depth': 9, 'subsample': 0.6880518261511787, 'colsample_bytree': 0.7029950803560996, 'lambda': 1.1293229234463227, 'alpha': 1.8792872838055739, 'min_child_weight': 17}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:13,115] Trial 28 finished with value: 45150.70426969315 and parameters: {'learning_rate': 0.015845211834712686, 'max_depth': 8, 'subsample': 0.581903498416401, 'colsample_bytree': 0.6819342726902876, 'lambda': 2.71338773160831, 'alpha': 1.039481079702559, 'min_child_weight': 20}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:14,349] Trial 29 finished with value: 45614.70935644179 and parameters: {'learning_rate': 0.03140427667972973, 'max_depth': 9, 'subsample': 0.6938757176214334, 'colsample_bytree': 0.7135203688622159, 'lambda': 0.9118027608965584, 'alpha': 2.0583462767183547, 'min_child_weight': 16}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:15,489] Trial 30 finished with value: 45627.56297122737 and parameters: {'learning_rate': 0.04378037299142442, 'max_depth': 8, 'subsample': 0.5759002237398558, 'colsample_bytree': 0.5101863341897668, 'lambda': 2.349209766265454, 'alpha': 0.6931254717070903, 'min_child_weight': 19}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:16,819] Trial 31 finished with value: 45515.83763004561 and parameters: {'learning_rate': 0.02185176173334651, 'max_depth': 7, 'subsample': 0.6623168223851921, 'colsample_bytree': 0.8017295565242969, 'lambda': 0.7424342203308916, 'alpha': 1.1702929102229174, 'min_child_weight': 17}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:17,912] Trial 32 finished with value: 45081.93097102788 and parameters: {'learning_rate': 0.018908475008443802, 'max_depth': 6, 'subsample': 0.7562249460499901, 'colsample_bytree': 0.7371999508718736, 'lambda': 1.289344920955976, 'alpha': 2.450273744257295, 'min_child_weight': 19}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:18,862] Trial 33 finished with value: 45488.664395605 and parameters: {'learning_rate': 0.027326420277702813, 'max_depth': 6, 'subsample': 0.743369168608564, 'colsample_bytree': 0.7342180994744038, 'lambda': 2.3430300222862503, 'alpha': 2.569394534267222, 'min_child_weight': 19}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:20,740] Trial 34 finished with value: 45202.995265688165 and parameters: {'learning_rate': 0.01794619825425454, 'max_depth': 10, 'subsample': 0.7120975808077383, 'colsample_bytree': 0.8473495714720962, 'lambda': 3.3253512411326653, 'alpha': 3.861688807491082, 'min_child_weight': 16}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:22,459] Trial 35 finished with value: 44925.497958446394 and parameters: {'learning_rate': 0.01376942403831523, 'max_depth': 7, 'subsample': 0.7619654834222299, 'colsample_bytree': 0.5932529358896796, 'lambda': 1.1203647321678156, 'alpha': 2.5223750759165386, 'min_child_weight': 19}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:24,804] Trial 36 finished with value: 45217.30281168323 and parameters: {'learning_rate': 0.013826528218330488, 'max_depth': 10, 'subsample': 0.670152878448949, 'colsample_bytree': 0.5889414196193148, 'lambda': 0.7932224662557938, 'alpha': 1.6425613091379827, 'min_child_weight': 5}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:25,635] Trial 37 finished with value: 46132.96957467779 and parameters: {'learning_rate': 0.06745429629700607, 'max_depth': 7, 'subsample': 0.724131311891632, 'colsample_bytree': 0.6768931132977469, 'lambda': 2.210298322306523, 'alpha': 0.4445605399676116, 'min_child_weight': 17}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:27,811] Trial 38 finished with value: 44905.27418504961 and parameters: {'learning_rate': 0.012689567868404826, 'max_depth': 8, 'subsample': 0.5964106285343735, 'colsample_bytree': 0.6073693688513953, 'lambda': 3.8555893882305816, 'alpha': 3.068187513184743, 'min_child_weight': 20}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:30,008] Trial 39 finished with value: 44962.074817333254 and parameters: {'learning_rate': 0.013030491200763458, 'max_depth': 8, 'subsample': 0.5135520802434446, 'colsample_bytree': 0.5975134642122956, 'lambda': 4.271960122207904, 'alpha': 4.426279549025722, 'min_child_weight': 20}. Best is trial 25 with value: 44856.602246820126.
# [I 2025-12-09 21:03:33,640] Trial 40 finished with value: 44833.41426701921 and parameters: {'learning_rate': 0.012458046644799402, 'max_depth': 11, 'subsample': 0.5098146632519004, 'colsample_bytree': 0.5893254306685181, 'lambda': 3.998391603853768, 'alpha': 4.498797248690466, 'min_child_weight': 20}. Best is trial 40 with value: 44833.41426701921.
. Best is trial 56 with value: 44690.58744628705.
# [I 2025-12-09 21:04:47,524] Trial 62 finished with value: 44801.926032396834 and parameters: {'learning_rate': 0.012122520938613017, 'max_depth': 11, 'subsample': 0.5633209634036811, 'colsample_bytree': 0.557980759293882, 'lambda': 2.939909626167217, 'alpha': 5.107097211187434, 'min_child_weight': 11}. Best is trial 56 with value: 44690.58744628705.
# [I 2025-12-09 21:04:50,721] Trial 63 finished with value: 44906.47706218367 and parameters: {'learning_rate': 0.01302509720440848, 'max_depth': 12, 'subsample': 0.5016772626790519, 'colsample_bytree': 0.5866458038255297, 'lambda': 3.14919123633762, 'alpha': 6.565406053977896, 'min_child_weight': 12}. Best is trial 56 with value: 44690.58744628705.
# [I 2025-12-09 21:04:54,236] Trial 64 finished with value: 44760.88914932606 and parameters: {'learning_rate': 0.010010204127147738, 'max_depth': 11, 'subsample': 0.5639453489191033, 'colsample_bytree': 0.6198422594324058, 'lambda': 2.870774895886652, 'alpha': 5.221994071886112, 'min_child_weight': 10}. Best is trial 56 with value: 44690.58744628705.
# [I 2025-12-09 21:04:58,529] Trial 65 finished with value: 44800.14146193183 and parameters: {'learning_rate': 0.010013616923207565, 'max_depth': 12, 'subsample': 0.5648015942448674, 'colsample_bytree': 0.6191704163534928, 'lambda': 2.7224490953853153, 'alpha': 5.082584301214585, 'min_child_weight': 10}. Best is trial 56 with value: 44690.58744628705.
# [I 2025-12-09 21:05:02,704] Trial 66 finished with value: 44803.128622391916 and parameters: {'learning_rate': 0.010006031770966685, 'max_depth': 11, 'subsample': 0.565187989861065, 'colsample_bytree': 0.5502849149760201, 'lambda': 2.841781012598242, 'alpha': 5.223880587613561, 'min_child_weight': 10}. Best is trial 56 with value: 44690.58744628705.
# [I 2025-12-09 21:05:06,358] Trial 67 finished with value: 44785.04146693853 and parameters: {'learning_rate': 0.010134428759771259, 'max_depth': 11, 'subsample': 0.5631040352001129, 'colsample_bytree': 0.5469094778390308, 'lambda': 2.8552013264191736, 'alpha': 6.03226575997306, 'min_child_weight': 9}. Best is trial 56 with value: 44690.58744628705.
# [I 2025-12-09 21:05:09,416] Trial 68 finished with value: 44977.23044711641 and parameters: {'learning_rate': 0.010154853231675828, 'max_depth': 10, 'subsample': 0.6196923709810683, 'colsample_bytree': 0.6318789539310995, 'lambda': 2.7043669383903195, 'alpha': 5.931985121805482, 'min_child_weight': 9}. Best is trial 56 with value: 44690.58744628705.
# [I 2025-12-09 21:05:10,830] Trial 69 finished with value: 47820.1021707302 and parameters: {'learning_rate': 0.09800864772912674, 'max_depth': 11, 'subsample': 0.5692845946642389, 'colsample_bytree': 0.6152094845093485, 'lambda': 1.9179965671879857, 'alpha': 6.426396531859769, 'min_child_weight': 10}. Best is trial 56 with value: 44690.58744628705.

# %%
print("Best RMSE:", study.best_value)
print("Best parameters:", study.best_params)
# Out:
# Best RMSE: 44690.58744628705
# Best parameters: {'learning_rate': 0.01146265235811284, 'max_depth': 11, 'subsample': 0.5693286009880982, 'colsample_bytree': 0.5745635245894778, 'lambda': 4.182988084688336, 'alpha': 3.505903048241581, 'min_child_weight': 12}

# %% [markdown]
# ## XIV. Train the final model

# %%
best_params = study.best_params
best_params.update({
    'tree_method': 'hist',
    'predictor': 'gpu_predictor',
    'device': 'gpu',
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
})

# %%
final_model = XGBRegressor(
    **best_params,
    n_estimators=2000,
    verbosity=1,  # Set verbosity to a lower value (0 = silent, 1 = warning, etc.)
    random_state=42
)

# %%
final_model.fit(
    X_train, y_train,
    eval_set=[(X_valid, y_valid)],
    verbose=50  # Output logs after 50 boosting rounds
)
# Out:
# [0]	validation_0-rmse:47725.40045
# [50]	validation_0-rmse:45918.99460
# [100]	validation_0-rmse:45105.52415
# [150]	validation_0-rmse:44786.50391
# [200]	validation_0-rmse:44687.77588
# [250]	validation_0-rmse:44699.08134
# [300]	validation_0-rmse:44775.32666
# [350]	validation_0-rmse:44837.08552
# [400]	validation_0-rmse:44920.63282
# [450]	validation_0-rmse:45031.36983
# [500]	validation_0-rmse:45133.97977
# [550]	validation_0-rmse:45217.54837
# [600]	validation_0-rmse:45300.43087
# [650]	validation_0-rmse:45362.54756
# [700]	validation_0-rmse:45513.83311
# [750]	validation_0-rmse:45601.66944
# [800]	validation_0-rmse:45672.09578
# [850]	validation_0-rmse:45790.77779
# [900]	validation_0-rmse:45882.55865
# [950]	validation_0-rmse:45996.54309
# [1000]	validation_0-rmse:46107.80473
# [1050]	validation_0-rmse:46166.51071
# [1100]	validation_0-rmse:46244.03587
# [1150]	validation_0-rmse:46337.84103
# [1200]	validation_0-rmse:46435.37153
# [1250]	validation_0-rmse:46498.48093
# [1300]	validation_0-rmse:46581.66805
# [1350]	validation_0-rmse:46662.48559
# [1400]	validation_0-rmse:46733.22993
# [1450]	validation_0-rmse:46813.43782
# [1500]	validation_0-rmse:46871.65322
# [1550]	validation_0-rmse:46983.10864
# [1600]	validation_0-rmse:47048.50002
# [1650]	validation_0-rmse:47176.72579
# [1700]	validation_0-rmse:47235.87888
# [1750]	validation_0-rmse:47305.58931
# [1800]	validation_0-rmse:47400.69382
# [1850]	validation_0-rmse:47446.97354
# [1900]	validation_0-rmse:47511.63370
# [1950]	validation_0-rmse:47557.67735
# [1999]	validation_0-rmse:47609.97322
# XGBRegressor(alpha=3.505903048241581, base_score=None, booster=None,
#              callbacks=None, colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.5745635245894778, device='gpu',
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric='rmse', feature_types=None, feature_weights=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, lambda=4.182988084688336,
#              learning_rate=0.01146265235811284, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=11, max_leaves=None,
#              min_child_weight=12, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=2000, ...)

# %%
y_pred_test = final_model.predict(X_test)

# %% [markdown]
# ## XV. Analysis of results

# %%
epsilon = 1e-6
rmse = mean_squared_error(y_test, y_pred_test) ** 0.5
mae = mean_absolute_error(y_test, y_pred_test)
mape = np.mean(np.abs((y_test - y_pred_test) / (np.abs(y_test) + epsilon))) * 100

# %%
print("\nTEST METRICS")
print(f"RMSE: {rmse:.4f}")
print(f"MAE : {mae:.4f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# TEST METRICS
# RMSE: 50364.5492
# MAE : 10019.3850
# MAPE: 12610119015.10%

# %%
# inspect target scale & extremes
import numpy as np
s = y_train
print("count", len(s))
print("min", np.min(s), "median", np.median(s), "mean", np.mean(s), "max", np.max(s))
print("quantiles", np.quantile(s, [0.5,0.75,0.9,0.95,0.99]))
# Out:
# count 473547
# min -7951559.879999999 median 0.0 mean -38.631114989642 max 8022838.260000002
# quantiles [    0.      672.16   5532.1   15777.68  90067.878]

# %% [markdown]
# Even after hyperparameter tuning....... LÕPETA
