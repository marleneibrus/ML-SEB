# %% [markdown]
# # Preparing cashflow features for an training a clustered XGBoost model

# %% [markdown]
# ### Project members:
# - Marlene Ibrus
# - Maare Karmen Oras
# - Aleksandr Volžinski

# %% [markdown]
# In this file...

# %% [markdown]
# ## I. Imports, User Configuration and Loading Data

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import os
import joblib
import math
from k_means_constrained import KMeansConstrained
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import mean_squared_error, mean_absolute_error
import xgboost as xgb
import optuna

# %%
USE_GPU = True # set False if no GPU
DEVICE = 'cuda' if USE_GPU else 'cpu'
TREE_METHOD = 'hist' if USE_GPU else 'hist'
OPTUNA_TRIALS = 40 # set higher (100-200) for better tuning
GLOBAL_CAP_PCT = 99.5 # cap target at this percentile during training
CLUSTERS = 5 # number of customer clusters
MIN_HISTORY_DAYS = 60 # minimum history for a customer to be modeled
OUTPUT_DIR = './models'
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
df_customer = pd.read_csv('../Data/synthetic_sme_customers_processed.csv')

# %%
df_transaction = pd.read_csv('../Data/synthetic_sme_transactions_processed.csv')

# %% [markdown]
# ## II. Create daily `net_flow` per Customer

# %%
df = df_transaction.copy()
df['BookingDatetime'] = pd.to_datetime(df['BookingDatetime'], errors='coerce')

# %%
# signed flow
df['flow'] = np.where(df['D_C'] == 'D', df['Amount_EUR'], -df['Amount_EUR'])

# %%
# aggregate to daily net_flow
daily_cashflow = (
df.groupby(['cust_id', pd.Grouper(key='BookingDatetime', freq='D')])['flow']
.sum()
.reset_index()
.rename(columns={'BookingDatetime':'date','flow':'net_flow'})
)

# %%
# Reindex per customer (fill missing days with 0)
full_rows = []
for cust, g in daily_cashflow.groupby('cust_id'):
    g = g.sort_values('date').set_index('date')
    idx = pd.date_range(g.index.min(), g.index.max(), freq='D')
    g2 = g.reindex(idx).rename_axis('date').reset_index()
    g2['cust_id'] = cust
    g2['net_flow'] = g2['net_flow'].fillna(0.0)
    full_rows.append(g2)

# %%
full_daily = pd.concat(full_rows, ignore_index=True)
print(f"Full daily shape: {full_daily.shape}")
# Out:
# Full daily shape: (682967, 3)

# %%
full_daily.head()
# Out:
#         date                                            cust_id  net_flow
# 0 2023-01-01  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f... -0.020048
# 1 2023-01-02  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 2 2023-01-03  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 3 2023-01-04  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 4 2023-01-05  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000

# %% [markdown]
# ## III. Create 7-day target

# %%
full_daily = full_daily.sort_values(['cust_id','date']).reset_index(drop=True)
full_daily['target_7d'] = (
    full_daily.groupby('cust_id')['net_flow']
        .transform(lambda x: x.rolling(window=7, min_periods=7).sum().shift(-7))
)

# %%
# drop rows where target is NaN (last up-to-7 days)
full_daily = full_daily[~full_daily['target_7d'].isna()].reset_index(drop=True)
print(f"After target creation: {full_daily.shape}")
# Out:
# After target creation: (676261, 4)

# %%
full_daily.head()
# Out:
#         date                                            cust_id  net_flow  \
# 0 2023-01-01  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f... -0.020048
# 1 2023-01-02  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 2 2023-01-03  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 3 2023-01-04  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 4 2023-01-05  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
#
#    target_7d
# 0    2.00481
# 1    2.00481
# 2    2.00481
# 3    2.00481
# 4    2.00481

# %% [markdown]
# ## IV. Feature Engineering

# %%
# rolling windows
windows = [7,14,30,90]
for w in windows:
    full_daily[f'roll_sum_{w}'] = full_daily.groupby('cust_id')['net_flow'].transform(lambda x: x.rolling(window=w, min_periods=1).sum())
    full_daily[f'roll_mean_{w}'] = full_daily.groupby('cust_id')['net_flow'].transform(lambda x: x.rolling(window=w, min_periods=1).mean())
    full_daily[f'roll_std_{w}'] = full_daily.groupby('cust_id')['net_flow'].transform(lambda x: x.rolling(window=w, min_periods=1).std().fillna(0))
    full_daily[f'roll_count_nz_{w}'] = full_daily.groupby('cust_id')['net_flow'].transform(lambda x: x.rolling(window=w, min_periods=1).apply(lambda s: np.sum(s!=0)))

# %%
full_daily.head()
# Out:
#         date                                            cust_id  net_flow  \
# 0 2023-01-01  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f... -0.020048
# 1 2023-01-02  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 2 2023-01-03  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 3 2023-01-04  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 4 2023-01-05  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
#
#    target_7d  roll_sum_7  roll_mean_7  roll_std_7  roll_count_nz_7  \
# 0    2.00481   -0.020048    -0.020048    0.000000              1.0
# 1    2.00481   -0.020048    -0.010024    0.014176              1.0
# 2    2.00481   -0.020048    -0.006683    0.011575              1.0
# 3    2.00481   -0.020048    -0.005012    0.010024              1.0
# 4    2.00481   -0.020048    -0.004010    0.008966              1.0
#
#    roll_sum_14  roll_mean_14  ...  std_flow_y  total_flow_y  n_days_y  \
# 0    -0.020048     -0.020048  ...   1701.5551  -8333.792768       715
# 1    -0.020048     -0.010024  ...   1701.5551  -8333.792768       715
# 2    -0.020048     -0.006683  ...   1701.5551  -8333.792768       715
# 3    -0.020048     -0.005012  ...   1701.5551  -8333.792768       715
# 4    -0.020048     -0.004010  ...   1701.5551  -8333.792768       715
#
#      max_flow_y  active_days_90_y  customer_type  parent_company_flag  \
# 0  14033.666764              49.0            SME                    1
# 1  14033.666764              49.0            SME                    1
# 2  14033.666764              49.0            SME                    1
# 3  14033.666764              49.0            SME                    1
# 4  14033.666764              49.0            SME                    1
#
#    CUST_GRP_ID  language  age
# 0          NaN       RUS   -1
# 1          NaN       RUS   -1
# 2          NaN       RUS   -1
# 3          NaN       RUS   -1
# 4          NaN       RUS   -1
#
# [5 rows x 44 columns]

# %%
# lags and baseline
full_daily["lag_1"] = (
    full_daily.groupby("cust_id")["net_flow"]
    .shift(1)
    .fillna(0)
)

# Baseline: previous 7-day sum
full_daily["lag_7_sum"] = (
    full_daily.groupby("cust_id")["net_flow"]
    .transform(lambda x: x.shift(1).rolling(7, min_periods=1).sum())
    .fillna(0)
)

# %%
full_daily['dayofweek'] = full_daily['date'].dt.dayofweek
full_daily['is_weekend'] = full_daily['dayofweek'].isin([5,6]).astype(int)
full_daily['day'] = full_daily['date'].dt.day
full_daily['month'] = full_daily['date'].dt.month
full_daily['year'] = full_daily['date'].dt.year

# %%
# quick activity features per customer (aggregation)
agg = (
    full_daily.groupby("cust_id")["net_flow"]
    .agg(['mean','std','sum','count','max'])
    .rename(columns={
        'mean':'mean_flow',
        'std':'std_flow',
        'sum':'total_flow',
        'count':'n_days',
        'max':'max_flow'
    })
    .reset_index()
)

# %%
# active_days = count non-zero days in last 90 days (approx)
recent = full_daily[full_daily['date'] >= (full_daily['date'].max() - pd.Timedelta(days=90))]
recent_agg = (
    recent.groupby('cust_id')['net_flow']
    .apply(lambda x: np.sum(x!=0)).reset_index().rename(columns={'net_flow':'active_days_90'})
)

# %%
agg = agg.merge(recent_agg, on='cust_id', how='left').fillna(0)

# %%
full_daily = full_daily.merge(agg, on="cust_id", how="left")

# %%
full_daily.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676261 entries, 0 to 676260
# Data columns (total 50 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date                 676261 non-null  datetime64[ns]
#  1   cust_id              676261 non-null  object
#  2   net_flow             676261 non-null  float64
#  3   target_7d            676261 non-null  float64
#  4   roll_sum_7           676261 non-null  float64
#  5   roll_mean_7          676261 non-null  float64
#  6   roll_std_7           676261 non-null  float64
#  7   roll_count_nz_7      676261 non-null  float64
#  8   roll_sum_14          676261 non-null  float64
#  9   roll_mean_14         676261 non-null  float64
#  10  roll_std_14          676261 non-null  float64
#  11  roll_count_nz_14     676261 non-null  float64
#  12  roll_sum_30          676261 non-null  float64
#  13  roll_mean_30         676261 non-null  float64
#  14  roll_std_30          676261 non-null  float64
#  15  roll_count_nz_30     676261 non-null  float64
#  16  roll_sum_90          676261 non-null  float64
#  17  roll_mean_90         676261 non-null  float64
#  18  roll_std_90          676261 non-null  float64
#  19  roll_count_nz_90     676261 non-null  float64
#  20  lag_1                676261 non-null  float64
#  21  lag_7_sum            676261 non-null  float64
#  22  dayofweek            676261 non-null  int32
#  23  is_weekend           676261 non-null  int64
#  24  day                  676261 non-null  int32
#  25  month                676261 non-null  int32
#  26  year                 676261 non-null  int32
#  27  mean_flow_x          676261 non-null  float64
#  28  std_flow_x           676261 non-null  float64
#  29  total_flow_x         676261 non-null  float64
#  30  n_days_x             676261 non-null  int64
#  31  max_flow_x           676261 non-null  float64
#  32  active_days_90_x     676261 non-null  float64
#  33  mean_flow_y          676261 non-null  float64
#  34  std_flow_y           676261 non-null  float64
#  35  total_flow_y         676261 non-null  float64
#  36  n_days_y             676261 non-null  int64
#  37  max_flow_y           676261 non-null  float64
#  38  active_days_90_y     676261 non-null  float64
#  39  customer_type        676261 non-null  object
#  40  parent_company_flag  676261 non-null  int64
#  41  CUST_GRP_ID          229063 non-null  object
#  42  language             676261 non-null  object
#  43  age                  676261 non-null  int64
#  44  mean_flow            676261 non-null  float64
#  45  std_flow             676261 non-null  float64
#  46  total_flow           676261 non-null  float64
#  47  n_days               676261 non-null  int64
#  48  max_flow             676261 non-null  float64
#  49  active_days_90       676261 non-null  float64
# dtypes: datetime64[ns](1), float64(35), int32(4), int64(6), object(4)
# memory usage: 247.7+ MB

# %%
agg = full_daily.copy()

# %%
# merge static customer data
cust_static = df_customer.copy()
if 'BRTH_DT' in cust_static.columns:
    cust_static['BRTH_DT'] = pd.to_datetime(cust_static['BRTH_DT'], errors='coerce')
    latest_date = full_daily['date'].max()
    cust_static['age'] = ((latest_date - cust_static['BRTH_DT']).dt.days // 365).fillna(-1).astype(int)
else:
    cust_static['age'] = -1

# %%
keep_cols = ['cust_id','customer_type','parent_company_flag','CUST_GRP_ID','language','age']
keep_cols = [c for c in keep_cols if c in cust_static.columns]
cust_static_small = cust_static[keep_cols]
agg = agg.merge(cust_static_small, on='cust_id', how='left')

# %%
agg.head()
# Out:
#         date                                            cust_id  net_flow  \
# 0 2023-01-01  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f... -0.020048
# 1 2023-01-02  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 2 2023-01-03  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 3 2023-01-04  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
# 4 2023-01-05  00feb0ff373287a3b1b210369f5aef9bfffd5d02f6bc8f...  0.000000
#
#    target_7d  roll_sum_7  roll_mean_7  roll_std_7  roll_count_nz_7  \
# 0    2.00481   -0.020048    -0.020048    0.000000              1.0
# 1    2.00481   -0.020048    -0.010024    0.014176              1.0
# 2    2.00481   -0.020048    -0.006683    0.011575              1.0
# 3    2.00481   -0.020048    -0.005012    0.010024              1.0
# 4    2.00481   -0.020048    -0.004010    0.008966              1.0
#
#    roll_sum_14  roll_mean_14  ...   std_flow   total_flow  n_days  \
# 0    -0.020048     -0.020048  ...  1701.5551 -8333.792768     715
# 1    -0.020048     -0.010024  ...  1701.5551 -8333.792768     715
# 2    -0.020048     -0.006683  ...  1701.5551 -8333.792768     715
# 3    -0.020048     -0.005012  ...  1701.5551 -8333.792768     715
# 4    -0.020048     -0.004010  ...  1701.5551 -8333.792768     715
#
#        max_flow  active_days_90  customer_type_y  parent_company_flag_y  \
# 0  14033.666764            49.0              SME                      1
# 1  14033.666764            49.0              SME                      1
# 2  14033.666764            49.0              SME                      1
# 3  14033.666764            49.0              SME                      1
# 4  14033.666764            49.0              SME                      1
#
#    CUST_GRP_ID_y  language_y  age_y
# 0            NaN         RUS     -1
# 1            NaN         RUS     -1
# 2            NaN         RUS     -1
# 3            NaN         RUS     -1
# 4            NaN         RUS     -1
#
# [5 rows x 55 columns]

# %%
agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 676261 entries, 0 to 676260
# Data columns (total 55 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   date                   676261 non-null  datetime64[ns]
#  1   cust_id                676261 non-null  object
#  2   net_flow               676261 non-null  float64
#  3   target_7d              676261 non-null  float64
#  4   roll_sum_7             676261 non-null  float64
#  5   roll_mean_7            676261 non-null  float64
#  6   roll_std_7             676261 non-null  float64
#  7   roll_count_nz_7        676261 non-null  float64
#  8   roll_sum_14            676261 non-null  float64
#  9   roll_mean_14           676261 non-null  float64
#  10  roll_std_14            676261 non-null  float64
#  11  roll_count_nz_14       676261 non-null  float64
#  12  roll_sum_30            676261 non-null  float64
#  13  roll_mean_30           676261 non-null  float64
#  14  roll_std_30            676261 non-null  float64
#  15  roll_count_nz_30       676261 non-null  float64
#  16  roll_sum_90            676261 non-null  float64
#  17  roll_mean_90           676261 non-null  float64
#  18  roll_std_90            676261 non-null  float64
#  19  roll_count_nz_90       676261 non-null  float64
#  20  lag_1                  676261 non-null  float64
#  21  lag_7_sum              676261 non-null  float64
#  22  dayofweek              676261 non-null  int32
#  23  is_weekend             676261 non-null  int64
#  24  day                    676261 non-null  int32
#  25  month                  676261 non-null  int32
#  26  year                   676261 non-null  int32
#  27  mean_flow_x            676261 non-null  float64
#  28  std_flow_x             676261 non-null  float64
#  29  total_flow_x           676261 non-null  float64
#  30  n_days_x               676261 non-null  int64
#  31  max_flow_x             676261 non-null  float64
#  32  active_days_90_x       676261 non-null  float64
#  33  mean_flow_y            676261 non-null  float64
#  34  std_flow_y             676261 non-null  float64
#  35  total_flow_y           676261 non-null  float64
#  36  n_days_y               676261 non-null  int64
#  37  max_flow_y             676261 non-null  float64
#  38  active_days_90_y       676261 non-null  float64
#  39  customer_type_x        676261 non-null  object
#  40  parent_company_flag_x  676261 non-null  int64
#  41  CUST_GRP_ID_x          229063 non-null  object
#  42  language_x             676261 non-null  object
#  43  age_x                  676261 non-null  int64
#  44  mean_flow              676261 non-null  float64
#  45  std_flow               676261 non-null  float64
#  46  total_flow             676261 non-null  float64
#  47  n_days                 676261 non-null  int64
#  48  max_flow               676261 non-null  float64
#  49  active_days_90         676261 non-null  float64
#  50  customer_type_y        676261 non-null  object
#  51  parent_company_flag_y  676261 non-null  int64
#  52  CUST_GRP_ID_y          229063 non-null  object
#  53  language_y             676261 non-null  object
#  54  age_y                  676261 non-null  int64
# dtypes: datetime64[ns](1), float64(35), int32(4), int64(8), object(7)
# memory usage: 273.5+ MB

# %%
agg.describe(include='all')
# Out:
#                                  date  \
# count                          676261
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-12-23 02:00:26.052662784
# min               2023-01-01 00:00:00
# 25%               2023-06-27 00:00:00
# 50%               2023-12-21 00:00:00
# 75%               2024-06-18 00:00:00
# max               2024-12-24 00:00:00
# std                               NaN
#
#                                                   cust_id      net_flow  \
# count                                              676261  6.762610e+05
# unique                                                958           NaN
# top     fedd8ec9267c5e537ccd33cc9aae6690be53e336df5423...           NaN
# freq                                                  724           NaN
# mean                                                  NaN  4.878278e+00
# min                                                   NaN -7.808635e+06
# 25%                                                   NaN  0.000000e+00
# 50%                                                   NaN  0.000000e+00
# 75%                                                   NaN  0.000000e+00
# max                                                   NaN  7.803744e+06
# std                                                   NaN  3.028598e+04
#
#            target_7d    roll_sum_7   roll_mean_7    roll_std_7  \
# count   6.762610e+05  6.762610e+05  6.762610e+05  6.762610e+05
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean    6.505535e+01  2.082151e+01 -4.651937e+00  4.841248e+03
# min    -7.951560e+06 -7.951560e+06 -3.612219e+06  0.000000e+00
# 25%    -4.923915e+02 -4.858005e+02 -6.962700e+01  1.111960e+01
# 50%     0.000000e+00  0.000000e+00  0.000000e+00  2.729095e+02
# 75%     6.561621e+02  6.546540e+02  9.382373e+01  1.602766e+03
# max     8.022838e+06  8.022838e+06  1.146120e+06  4.508648e+06
# std     5.678388e+04  5.784257e+04  9.769052e+03  3.127278e+04
#
#         roll_count_nz_7   roll_sum_14  roll_mean_14  ...  parent_company_flag  \
# count     676261.000000  6.762610e+05  6.762610e+05  ...        676261.000000
# unique              NaN           NaN           NaN  ...                  NaN
# top                 NaN           NaN           NaN  ...                  NaN
# freq                NaN           NaN           NaN  ...                  NaN
# mean           2.750799  4.465067e+01 -8.473188e+00  ...             0.675752
# min            0.000000 -8.012290e+06 -3.612219e+06  ...             0.000000
# 25%            1.000000 -1.012305e+03 -7.299385e+01  ...             0.000000
# 50%            2.000000  0.000000e+00  0.000000e+00  ...             1.000000
# 75%            4.000000  1.141780e+03  8.240566e+01  ...             1.000000
# max            7.000000  5.630463e+06  4.021759e+05  ...             1.000000
# std            2.163957  7.461064e+04  7.771123e+03  ...             0.468093
#
#                                               CUST_GRP_ID  language       age  \
# count                                              229063    676261  676261.0
# unique                                                320         3       NaN
# top     168427e00053657623db6be4f2b1a4d7a590c6a893de10...       EST       NaN
# freq                                                 1440    551346       NaN
# mean                                                  NaN       NaN      -1.0
# min                                                   NaN       NaN      -1.0
# 25%                                                   NaN       NaN      -1.0
# 50%                                                   NaN       NaN      -1.0
# 75%                                                   NaN       NaN      -1.0
# max                                                   NaN       NaN      -1.0
# std                                                   NaN       NaN       0.0
#
#             mean_flow       std_flow    total_flow         n_days  \
# count   676261.000000  676261.000000  6.762610e+05  676261.000000
# unique            NaN            NaN           NaN            NaN
# top               NaN            NaN           NaN            NaN
# freq              NaN            NaN           NaN            NaN
# mean         4.878278    8171.506804  8.313616e+03     710.912087
# min     -36268.970038       0.289466 -7.652753e+06     121.000000
# 25%         -9.213887     406.330439 -6.590077e+03     713.000000
# 50%         -0.015735    1317.508331 -8.474336e+00     723.000000
# 75%         12.895044    4986.364903  9.336012e+03     724.000000
# max       4712.515047  475690.948747  3.411861e+06     724.000000
# std        753.205590   29177.459896  3.130396e+05      43.878433
#
#             max_flow  active_days_90
# count   6.762610e+05    676261.00000
# unique           NaN             NaN
# top              NaN             NaN
# freq             NaN             NaN
# mean    6.948477e+04        33.72226
# min     1.967499e+00         0.00000
# 25%     3.591905e+03        12.00000
# 50%     1.136912e+04        29.00000
# 75%     4.425077e+04        50.00000
# max     7.803744e+06        91.00000
# std     2.960818e+05        25.31099
#
# [11 rows x 50 columns]

# %% [markdown]
# ## V. Customer Clustering

# %%
cluster_features = ['mean_flow','std_flow','total_flow','n_days','max_flow','active_days_90','roll_sum_7','roll_mean_7','roll_std_7','roll_count_nz_7','roll_sum_14','roll_mean_14','roll_std_14','roll_count_nz_14','roll_sum_30','roll_mean_30','roll_std_30','roll_count_nz_30','roll_sum_90','roll_mean_90','roll_std_90','roll_count_nz_90']
cluster_features = [c for c in cluster_features if c in agg.columns]
X_cluster = agg[cluster_features].fillna(0).copy()

# %%
# Log-transform skewed features to reduce dominance of whales
skewed = ['total_flow','max_flow','mean_flow']
for col in skewed:
    if col in X_cluster.columns:
        X_cluster[col] = np.sign(X_cluster[col]) * np.log1p(np.abs(X_cluster[col]))

# %%
scaler = RobustScaler()
X_scaled = scaler.fit_transform(X_cluster)

# %%
# Separate extreme whales defined as top 1% max_flow
whale_threshold = np.percentile(agg['max_flow'], 99)
whale_mask = agg['max_flow'] > whale_threshold
agg['is_whale'] = whale_mask

# %%
X_non_whale = X_scaled[~whale_mask.values]

# %%
n_clusters = 5  # adjust based on silhouette
gmm = GaussianMixture(n_components=n_clusters, random_state=42)
gmm_labels = gmm.fit_predict(X_non_whale)

# %%
agg['cluster'] = -1  # -1 for whales temporarily

# Assign non-whale clusters
agg.loc[~whale_mask, 'cluster'] = gmm_labels

# Assign whale cluster ID (e.g., max cluster + 1)
whale_cluster_id = agg['cluster'].max() + 1
agg.loc[whale_mask, 'cluster'] = whale_cluster_id

print(f"Whale cluster ID: {whale_cluster_id}, size: {whale_mask.sum()}")
# Out:
# Whale cluster ID: 5, size: 6465

# %%
sil_score = silhouette_score(X_non_whale, gmm_labels)
print(f"Silhouette score (non-whales): {sil_score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 sil_score = silhouette_score(X_non_whale, gmm_labels)
#       2 print(f"Silhouette score (non-whales): {sil_score:.4f}")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:138, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     136     else:
#     137         X, labels = X[indices], labels[indices]
# --> 138 return float(np.mean(silhouette_samples(X, labels, metric=metric, **kwds)))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\cluster\_unsupervised.py:302, in silhouette_samples(X, labels, metric, **kwds)
#     298 kwds["metric"] = metric
#     299 reduce_func = functools.partial(
#     300     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     301 )
# --> 302 results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func, **kwds))
#     303 intra_clust_dists, inter_clust_dists = results
#     304 intra_clust_dists = np.concatenate(intra_clust_dists)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\pairwise.py:2240, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2238 else:
#    2239     X_chunk = X[sl]
# -> 2240 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    2241 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    2242     metric, None
#    2243 ) is euclidean_distances:
#    2244     # zeroing diagonal, taking care of aliases of "euclidean",
#    2245     # i.e. "l2"
#    2246     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\pairwise.py:2476, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, ensure_all_finite, **kwds)
#    2473         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2474     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2476 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\pairwise.py:1960, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1957 X, Y, dtype = _return_float_dtype(X, Y)
#    1959 if effective_n_jobs(n_jobs) == 1:
# -> 1960     return func(X, Y, **kwds)
#    1962 # enforce a threading backend to prevent data communication overhead
#    1963 fd = delayed(_dist_wrapper)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\pairwise.py:388, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     382     if Y_norm_squared.shape != (1, Y.shape[0]):
#     383         raise ValueError(
#     384             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     385             f"Y_norm_squared of shape {original_shape}."
#     386         )
# --> 388 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\pairwise.py:441, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     438 if squared:
#     439     return distances
# --> 441 distances = _modify_in_place_if_numpy(xp, xp.sqrt, distances, out=distances)
#     442 return distances
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_array_api.py:979, in _modify_in_place_if_numpy(xp, func, out, *args, **kwargs)
#     977 def _modify_in_place_if_numpy(xp, func, *args, out=None, **kwargs):
#     978     if _is_numpy_namespace(xp):
# --> 979         func(*args, out=out, **kwargs)
#     980     else:
#     981         out = func(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
cluster_sizes = agg.groupby('cluster')['cust_id'].count()
print("Cluster sizes:\n", cluster_sizes)

# %%
cluster_summary = agg.groupby('cluster')[cluster_features + ['is_whale']].median()
print(cluster_summary)
# Out:
#           mean_flow       std_flow     total_flow  n_days      max_flow  \
# cluster
# 0         -0.013027     802.667719      -9.148030   721.0  6.903841e+03
# 1         -4.286018   14010.968593   -3085.933044   724.0  1.135379e+05
# 2          0.352151     318.608116     196.137000   481.0  2.963639e+03
# 3        521.101733  127477.240859  377277.654729   723.0  1.062702e+06
#
#          active_days_90  is_whale
# cluster
# 0                  25.0       0.0
# 1                  57.0       0.0
# 2                   0.0       0.0
# 3                  55.0       1.0

# %%
# Merge cluster label back to daily dataframe
full_daily = full_daily.merge(agg[['cust_id','cluster']], on='cust_id', how='left')

# %%
full_daily.describe(include='all')
# Out:
#                                  date  \
# count                          676261
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2023-12-23 02:00:26.052662784
# min               2023-01-01 00:00:00
# 25%               2023-06-27 00:00:00
# 50%               2023-12-21 00:00:00
# 75%               2024-06-18 00:00:00
# max               2024-12-24 00:00:00
# std                               NaN
#
#                                                   cust_id      net_flow  \
# count                                              676261  6.762610e+05
# unique                                                958           NaN
# top     fedd8ec9267c5e537ccd33cc9aae6690be53e336df5423...           NaN
# freq                                                  724           NaN
# mean                                                  NaN  4.878278e+00
# min                                                   NaN -7.808635e+06
# 25%                                                   NaN  0.000000e+00
# 50%                                                   NaN  0.000000e+00
# 75%                                                   NaN  0.000000e+00
# max                                                   NaN  7.803744e+06
# std                                                   NaN  3.028598e+04
#
#            target_7d    roll_sum_7   roll_mean_7    roll_std_7  \
# count   6.762610e+05  6.762610e+05  6.762610e+05  6.762610e+05
# unique           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN
# mean    6.505535e+01  2.082151e+01 -4.651937e+00  4.841248e+03
# min    -7.951560e+06 -7.951560e+06 -3.612219e+06  0.000000e+00
# 25%    -4.923915e+02 -4.858005e+02 -6.962700e+01  1.111960e+01
# 50%     0.000000e+00  0.000000e+00  0.000000e+00  2.729095e+02
# 75%     6.561621e+02  6.546540e+02  9.382373e+01  1.602766e+03
# max     8.022838e+06  8.022838e+06  1.146120e+06  4.508648e+06
# std     5.678388e+04  5.784257e+04  9.769052e+03  3.127278e+04
#
#         roll_count_nz_7   roll_sum_14  roll_mean_14  ...   roll_std_90  \
# count     676261.000000  6.762610e+05  6.762610e+05  ...  6.762610e+05
# unique              NaN           NaN           NaN  ...           NaN
# top                 NaN           NaN           NaN  ...           NaN
# freq                NaN           NaN           NaN  ...           NaN
# mean           2.750799  4.465067e+01 -8.473188e+00  ...  6.789758e+03
# min            0.000000 -8.012290e+06 -3.612219e+06  ...  0.000000e+00
# 25%            1.000000 -1.012305e+03 -7.299385e+01  ...  2.286846e+02
# 50%            2.000000  0.000000e+00  0.000000e+00  ...  8.596845e+02
# 75%            4.000000  1.141780e+03  8.240566e+01  ...  3.481428e+03
# max            7.000000  5.630463e+06  4.021759e+05  ...  2.554225e+06
# std            2.163957  7.461064e+04  7.771123e+03  ...  3.076013e+04
#
#         roll_count_nz_90         lag_1     lag_7_sum      dayofweek  \
# count      676261.000000  6.762610e+05  6.762610e+05  676261.000000
# unique               NaN           NaN           NaN            NaN
# top                  NaN           NaN           NaN            NaN
# freq                 NaN           NaN           NaN            NaN
# mean           33.324829  3.220474e+00  1.888568e+01       2.998409
# min             0.000000 -7.808635e+06 -7.951560e+06       0.000000
# 25%            14.000000  0.000000e+00 -4.824468e+02       1.000000
# 50%            28.000000  0.000000e+00  0.000000e+00       3.000000
# 75%            49.000000  0.000000e+00  6.514894e+02       5.000000
# max            90.000000  7.803744e+06  8.022838e+06       6.000000
# std            23.667135  3.026331e+04  5.780145e+04       2.002450
#
#            is_weekend            day          month           year  \
# count   676261.000000  676261.000000  676261.000000  676261.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         0.285847      15.615376       6.409474    2023.485848
# min          0.000000       1.000000       1.000000    2023.000000
# 25%          0.000000       8.000000       3.000000    2023.000000
# 50%          0.000000      16.000000       6.000000    2023.000000
# 75%          1.000000      23.000000       9.000000    2024.000000
# max          1.000000      31.000000      12.000000    2024.000000
# std          0.451817       8.776504       3.401562       0.499800
#
#               cluster
# count   676261.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean         0.333252
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          3.000000
# std          0.599717
#
# [11 rows x 28 columns]

# %% [markdown]
# ## VI. Prepare modeling dataframe and split

# %%
# features to use
feature_cols = [
    'net_flow', 'roll_sum_7','roll_sum_14','roll_sum_30','roll_sum_90',
    'roll_mean_7','roll_mean_14','roll_mean_30','roll_mean_90',
    'roll_std_7','roll_std_14','roll_std_30','roll_std_90',
    'roll_count_nz_7','roll_count_nz_14','roll_count_nz_30','roll_count_nz_90',
    'lag_1','lag_7_sum','dayofweek','is_weekend','day','month','year','age'
]
feature_cols = [c for c in feature_cols if c in full_daily.columns]

# %%
# merge also some static cats
for c in ['customer_type','parent_company_flag','CUST_GRP_ID','language']:
    if c in cust_static_small.columns:
        full_daily[c] = full_daily['cust_id'].map(cust_static_small.set_index('cust_id')[c])
        if full_daily[c].dtype == object or full_daily[c].dtype.name=='category':
            full_daily[c] = full_daily[c].astype('category').cat.codes.fillna(-1).astype(int)
        else:
            full_daily[c] = pd.to_numeric(full_daily[c], errors='coerce').fillna(-1).astype(int)
        feature_cols.append(c)

# %%
# drop rows with too short history (optionally)
cust_history = full_daily.groupby('cust_id')['date'].nunique().reset_index().rename(columns={'date':'history_days'})
full_daily = full_daily.merge(cust_history,on='cust_id',how='left')
full_daily = full_daily[full_daily['history_days'] >= MIN_HISTORY_DAYS]

# %%
# split by date globally (chronological)
full_daily = full_daily.sort_values('date')
train_end = full_daily['date'].quantile(0.70)
valid_end = full_daily['date'].quantile(0.85)

# %%
train_df = full_daily[full_daily['date'] <= train_end]
valid_df = full_daily[(full_daily['date'] > train_end) & (full_daily['date'] <= valid_end)]
test_df = full_daily[full_daily['date'] > valid_end]

# %%
print('Train/Valid/Test shapes:', train_df.shape, valid_df.shape, test_df.shape)
# Out:
# Train/Valid/Test shapes: (473873, 33) (101394, 33) (100994, 33)

# %% [markdown]
# ## VII. Modeling Helpers

# %%
def make_dmatrix(X, y=None):
    if y is None:
        return xgb.DMatrix(X)
    return xgb.DMatrix(X, label=y)

# %%
def safe_mape(y_true, y_pred):
    eps = 1e-6
    return np.mean(np.abs((y_true - y_pred) / (np.abs(y_true) + eps))) * 100

# %%
# function to run optuna per-cluster
def tune_and_train_cluster(cluster_id, train_df, valid_df, test_df, feature_cols, n_trials=30, cap_pct=GLOBAL_CAP_PCT):
    print(f"\n--- Cluster {cluster_id} tuning & training ---")
    # filter by cluster
    tr = train_df[train_df['cluster']==cluster_id]
    va = valid_df[valid_df['cluster']==cluster_id]
    te = test_df[test_df['cluster']==cluster_id]
    
    if len(tr) < 1000 or tr['cust_id'].nunique() < 10:
        print('Cluster too small for tuning (falling back to global params).')
        return None
    
    X_tr = tr[feature_cols].fillna(0)
    X_va = va[feature_cols].fillna(0)
    X_te = te[feature_cols].fillna(0)
    
    y_tr = tr['target_7d'].values
    y_va = va['target_7d'].values
    y_te = te['target_7d'].values
    
    # cap training target to reduce tail influence
    cap = np.percentile(y_tr, cap_pct)
    y_tr_cap = np.clip(y_tr, -cap, cap)

    # log1p transform of positive part (we predict positive flows primarily)
    # To keep sign info, we can model positive and negative separately, but here we model signed values using signed log
    def sign_log1p(x):
        return np.sign(x) * np.log1p(np.abs(x))
    def inv_sign_log1p(y):
        return np.sign(y) * (np.expm1(np.abs(y)))
    
    y_tr_trans = sign_log1p(y_tr_cap)
    y_va_trans = sign_log1p(y_va)
    
    dtrain = make_dmatrix(X_tr, y_tr_trans)
    dvalid = make_dmatrix(X_va, y_va_trans)

    def objective(trial):
        params = {
            'objective': 'reg:squarederror',
            'eval_metric': 'rmse',
            'tree_method': TREE_METHOD,
            'device': DEVICE,
            'eta': trial.suggest_float('eta', 0.01, 0.2, log=True),
            'max_depth': trial.suggest_int('max_depth', 4, 10),
            'subsample': trial.suggest_float('subsample', 0.6, 1.0),
            'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
            'alpha': trial.suggest_float('alpha', 0.0, 10.0),
            'lambda': trial.suggest_float('lambda', 0.0, 10.0),
            'min_child_weight': trial.suggest_int('min_child_weight', 1, 50)
        }
        evals = [(dtrain, 'train'), (dvalid, 'valid')]
        bst = xgb.train(
            params,
            dtrain,
            num_boost_round=2000,
            evals=evals,
            early_stopping_rounds=50,
            verbose_eval=False
        )
        pred_va = bst.predict(dvalid)
        # inverse transform
        pred_va_inv = inv_sign_log1p(pred_va)
        rmse = mean_squared_error(y_va, pred_va_inv) ** 0.5
        return rmse

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=n_trials)
    
    print('Best RMSE on validation (from objective):', study.best_value)
    print('Best params:', study.best_params)
    
    # Train final model on combined train+valid
    combo_X = pd.concat([X_tr, X_va], axis=0)
    combo_y = np.concatenate([y_tr_trans, y_va_trans], axis=0)
    dcombo = make_dmatrix(combo_X, combo_y)

    best_params = study.best_params
    params_final = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'tree_method': TREE_METHOD,
        'device': DEVICE,
        'eta': best_params['eta'],
        'max_depth': best_params['max_depth'],
        'subsample': best_params['subsample'],
        'colsample_bytree': best_params['colsample_bytree'],
        'alpha': best_params['alpha'],
        'lambda': best_params['lambda'],
        'min_child_weight': best_params['min_child_weight']
    }
    
    
    evals_final = [(dcombo, 'train'), (dvalid, 'valid')]
    bst_final = xgb.train(
        params_final,
        dcombo,
        num_boost_round=2000,
        evals=evals_final,
        early_stopping_rounds=50,
        verbose_eval=50
    )

    # Evaluate on test
    dtest = make_dmatrix(X_te)
    pred_te = bst_final.predict(dtest)
    pred_te_inv = inv_sign_log1p(pred_te)
    
    rmse_test = mean_squared_error(y_te, pred_te_inv) ** 0.5
    mae_test = mean_absolute_error(y_te, pred_te_inv)
    mape_test = safe_mape(y_te, pred_te_inv)
    
    print(f"Cluster {cluster_id} TEST RMSE: {rmse_test:.2f}, MAE: {mae_test:.2f}, MAPE: {mape_test:.2f}%")
    
    # Save model
    model_path = os.path.join(OUTPUT_DIR, f'xgb_cluster_{cluster_id}.model')
    bst_final.save_model(model_path)
    print('Saved model to', model_path)
    
    # return performance and model
    return {
        'cluster': cluster_id,
        'model': bst_final,
        'rmse_test': rmse_test,
        'mae_test': mae_test,
        'mape_test': mape_test,
        'cap': cap
    }

# %%
# Separate model for clusters identified as whales
def whale_forecast(customer_df):
    df = customer_df.copy().sort_values("date")

    # Compute weekday
    df["weekday"] = df["date"].dt.weekday

    # 1) Seasonal Naive: mean flow on the same weekday for the last 8 weeks
    last_8_weeks = df[df["date"] >= df["date"].max() - pd.Timedelta(days=56)]
    seasonal_forecast = (
        last_8_weeks.groupby("weekday")["net_flow"]
        .mean()
        .reindex(range(7), fill_value=np.nan)
        .to_numpy()
    )

    # 2) Rolling median (30 days)
    median_30d = df[df["date"] >= df["date"].max() - pd.Timedelta(days=30)]["net_flow"].median()

    # 3) Last-7-day sum
    last7_sum = df[df["date"] >= df["date"].max() - pd.Timedelta(days=7)]["net_flow"].sum()

    # Build the 7-day forecast
    forecast = []

    for i in range(7):
        val = seasonal_forecast[i]

        # Fallbacks
        if np.isnan(val):
            if not np.isnan(median_30d):
                val = median_30d
            else:
                val = last7_sum / 7.0

        forecast.append(val)

    return np.array(forecast)

# %% [markdown]
# ## VIII. Training per-cluster models

# %%
results = []
all_predictions = []  # to store per-row predictions

for c in sorted(agg['cluster'].unique()):
    # subset test data for this cluster
    te = test_df[test_df['cluster'] == c]

    if len(te) == 0:
        continue  # skip empty clusters

    if c == 3:
        print(f"Cluster {c} is marked as whale cluster. Using whale_forecast for predictions.")

        # loop per customer in this cluster
        for cust_id, group in te.groupby('cust_id'):
            cust_history = daily_cashflow[daily_cashflow["cust_id"] == cust_id]
            preds = whale_forecast(cust_history)

            tmp = group.copy()
            tmp['y_pred'] = preds  # predicted 7-day flow
            all_predictions.append(tmp)
    
    else:
        # ---- use XGBoost / tuned model ----
        res = tune_and_train_cluster(c, train_df, valid_df, test_df, feature_cols,
                                     n_trials=OPTUNA_TRIALS, cap_pct=GLOBAL_CAP_PCT)

        # store per-row predictions
        dtest = xgb.DMatrix(te[feature_cols])
        te_preds = res['model'].predict(dtest)
        tmp = te.copy()
        tmp['y_pred'] = te_preds
        all_predictions.append(tmp)

        results.append(res)

# Combine all predictions into a single dataframe
pred_df = pd.concat(all_predictions, ignore_index=True)
# Out:
# --- Cluster 0 tuning & training ---
# [I 2025-12-10 01:27:02,821] A new study created in memory with name: no-name-6c8099cd-1fc0-4b5d-bfab-ce6113064801
# [I 2025-12-10 01:27:05,355] Trial 0 finished with value: 4061.823134869642 and parameters: {'eta': 0.07115584722422022, 'max_depth': 8, 'subsample': 0.666911675143514, 'colsample_bytree': 0.8799101733515802, 'alpha': 2.9799285333608183, 'lambda': 4.974638239690661, 'min_child_weight': 2}. Best is trial 0 with value: 4061.823134869642.
# [I 2025-12-10 01:27:11,468] Trial 1 finished with value: 4047.6763273579695 and parameters: {'eta': 0.022232470093406422, 'max_depth': 8, 'subsample': 0.8359943542654238, 'colsample_bytree': 0.6950511913160214, 'alpha': 0.8575364369261174, 'lambda': 3.71044503553706, 'min_child_weight': 26}. Best is trial 1 with value: 4047.6763273579695.
# [1750]	train-rmse:0.56672	valid-rmse:0.48592
# [1800]	train-rmse:0.55652	valid-rmse:0.47775
# [1850]	train-rmse:0.54679	valid-rmse:0.46942
# [1900]	train-rmse:0.53758	valid-rmse:0.46155
# [1950]	train-rmse:0.52877	valid-rmse:0.45399
# [1999]	train-rmse:0.52074	valid-rmse:0.44754
# Cluster 2 TEST RMSE: 11182.20, MAE: 1261.79, MAPE: 937223725.74%
# Saved model to ./models\xgb_cluster_2.model
# Cluster 3 is marked as whale cluster. Using whale_forecast for predictions.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 20
#      17         preds = whale_forecast(cust_history)
#      19         tmp = group.copy()
# ---> 20         tmp['y_pred'] = preds  # predicted 7-day flow
#      21         all_predictions.append(tmp)
#      23 else:
#      24     # ---- use XGBoost / tuned model ----
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)
#    4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
#    4539         and value.ndim == 1
#    4540         and not isinstance(value.dtype, ExtensionDtype)
#    4541     ):
#    4542         # broadcast across multiple columns if necessary
#    4543         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5288, in DataFrame._sanitize_column(self, value)
#    5285     return _reindex_for_setitem(value, self.index)
#    5287 if is_list_like(value):
# -> 5288     com.require_length_match(value, self.index)
#    5289 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5290 if (
#    5291     isinstance(value, Index)
#    5292     and value.dtype == "object"
#    (...)
#    5295     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5296     # this deprecation
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (7) does not match length of index (114)

# %% [markdown]
# ## IX. Global evaluation and combining cluster predictions

# %%
preds = []
for c in sorted(agg['cluster'].unique()):
    te = test_df[test_df['cluster']==c]
    if te.empty:
        continue
    if c in whale_clusters:
        # baseline use
        p = te['lag_7_sum'].values
    else:
        # load model path
        model_path = os.path.join(OUTPUT_DIR, f'xgb_cluster_{c}.model')
        if not os.path.exists(model_path):
            print('Model missing for cluster', c)
            continue
        bst = xgb.Booster()
        bst.load_model(model_path)
        dte = xgb.DMatrix(te[feature_cols].fillna(0))
        p_raw = bst.predict(dte)
        # inverse transform
        p = np.sign(p_raw) * (np.expm1(np.abs(p_raw)))
    preds.append(pd.DataFrame({'cust_id': te['cust_id'].values, 'date': te['date'].values, 'y_true': te['target_7d'].values, 'y_pred': p}))

# %%
pred_df = pd.concat(preds, ignore_index=True)

# %%
global_rmse = math.sqrt(((pred_df['y_true'] - pred_df['y_pred'])**2).mean())
global_mae = (np.abs(pred_df['y_true'] - pred_df['y_pred']).mean())
global_mape = safe_mape(pred_df['y_true'].values, pred_df['y_pred'].values)

print(f"Global test RMSE: {global_rmse:.2f}, MAE: {global_mae:.2f}, MAPE: {global_mape:.2f}%")

# %%
# Per-cluster RMSE
per_cluster = pred_df.groupby('cust_id').apply(lambda g: math.sqrt(((g['y_true']-g['y_pred'])**2).mean())).reset_index(name='rmse_cust')
per_cluster = per_cluster.merge(agg[['cust_id','cluster']], on='cust_id', how='left')
cluster_rmse = per_cluster.groupby('cluster')['rmse_cust'].median().reset_index().rename(columns={'rmse_cust':'median_rmse_per_customer'})
print('\nMedian per-customer RMSE by cluster:')
print(cluster_rmse)

# %%
raw_cluster_rmse = []

for cluster_id, group in pred_df.merge(
        agg[['cust_id','cluster']], on='cust_id', how='left'
    ).groupby('cluster'):

    y_true = group['y_true'].values
    y_pred = group['y_pred'].values

    rmse = mean_squared_error(y_true, y_pred) ** 0.5
    raw_cluster_rmse.append((cluster_id, rmse))

raw_cluster_rmse = (
    pd.DataFrame(raw_cluster_rmse, columns=['cluster', 'raw_cluster_rmse'])
)

print("\nRAW RMSE per cluster (all rows pooled):")
print(raw_cluster_rmse)
